# %%
import pandas as pd

# %%
df = pd.read_csv(r'D:\dbt_test\bquxjob_4f815bb4_19dae359883.csv')

# %%
df.head()
# Out:
#    movie_sk                          title                   genre  \
# 0      7394  homecoming: a film by beyoncé      documentary, music
# 1      8289                     puppy love         comedy, romance
# 2      5248  money shot: the pornhub story             documentary
# 3       147                           gigi         comedy, romance
# 4      6349         running with the devil  crime, drama, thriller
#
#                               director  average_rating  weighted_rating  \
# 0                              beyoncé           8.100         7.018918
# 1  richard alan reid, nicholas fabiano           6.959         6.728141
# 2                    suzanne hillinger           5.781         6.427454
# 3                    vincente minnelli           6.220         6.539574
# 4                         jason cabell           5.415         6.333978
#
#    num_votes  log_votes  rating_diff popularity_level
# 0        342   2.535294     1.450812              low
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9993 entries, 0 to 9992
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   movie_sk          9993 non-null   int64
#  1   title             9993 non-null   object
#  2   genre             9993 non-null   object
#  3   director          9993 non-null   object
#  4   average_rating    9993 non-null   float64
#  5   weighted_rating   9993 non-null   float64
#  6   num_votes         9993 non-null   int64
#  7   log_votes         9993 non-null   float64
#  8   rating_diff       9993 non-null   float64
#  9   popularity_level  9993 non-null   object
# dtypes: float64(4), int64(2), object(4)
# memory usage: 780.8+ KB
